# %% [markdown]
# <a href="https://colab.research.google.com/github/shamiik/pandas/blob/main/pandasDataframe%26Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Dataframe**

# %%
import pandas as pd
df1= pd.DataFrame({'Name': ['sam','jenny','penny','remy'],'Marks': [100,96,100,78]})
df1
# Out:
#     Name  Marks
# 0    sam    100
# 1  jenny     96
# 2  penny    100
# 3   remy     78

# %% [markdown]
# ---
#
#
# **Builton Function DataFrame**
#
# *   head()
# *   tail()
# *   shape
# *   describe()

# %%
iris= pd.read_csv('/content/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ---
#
#
# **.iloc[  ] Methods**
# * to extract row & coloumns wrt their index

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.iloc[0:5, 0:2]
# Out:
#    Sepal.Length  Sepal.Width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
iris.iloc[0:4, 0:3]
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5

# %%
iris.iloc[20:30, 2:]
# Out:
#     Petal.Length  Petal.Width Species
# 20           1.7          0.2  setosa
# 21           1.5          0.4  setosa
# 22           1.0          0.2  setosa
# 23           1.7          0.5  setosa
# 24           1.9          0.2  setosa
# 25           1.6          0.2  setosa
# 26           1.6          0.4  setosa
# 27           1.5          0.2  setosa
# 28           1.4          0.2  setosa
# 29           1.6          0.2  setosa

# %% [markdown]
# **.loc Method**
# *  specific coloumn

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.loc[3:8,('Petal.Length','Species')]
# Out:
#    Petal.Length Species
# 3           1.5  setosa
# 4           1.4  setosa
# 5           1.7  setosa
# 6           1.4  setosa
# 7           1.5  setosa
# 8           1.4  setosa

# %% [markdown]
# **Dropping Columns**
# *  axis= 0 means row
# *  axis =1 means coloumn

# %%
iris.drop('Sepal.Width', axis=1)
# Out:
#      Sepal.Length  Petal.Length  Petal.Width    Species
# 0             5.1           1.4          0.2     setosa
# 1             4.9           1.4          0.2     setosa
# 2             4.7           1.3          0.2     setosa
# 3             4.6           1.5          0.2     setosa
# 4             5.0           1.4          0.2     setosa
# ..            ...           ...          ...        ...
# 145           6.7           5.2          2.3  virginica
# 146           6.3           5.0          1.9  virginica
# 147           6.5           5.2          2.0  virginica
# 148           6.2           5.4          2.3  virginica
# 149           5.9           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
iris.drop([3,5,7],axis=0)
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [147 rows x 5 columns]

# %% [markdown]
# # PAndas Function

# %%
iris.mean()
# Out:
# <ipython-input-18-7eed97565d6e>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris.mean()
# Sepal.Length    5.843333
# Sepal.Width     3.057333
# Petal.Length    3.758000
# Petal.Width     1.199333
# dtype: float64

# %%
iris.max()
# Out:
# Sepal.Length          7.9
# Sepal.Width           4.4
# Petal.Length          6.9
# Petal.Width           2.5
# Species         virginica
# dtype: object

# %%
iris.min()
# Out:
# Sepal.Length       4.3
# Sepal.Width        2.0
# Petal.Length       1.0
# Petal.Width        0.1
# Species         setosa
# dtype: object

# %%
iris.median()
# Out:
# <ipython-input-33-7f9b4600b8ea>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   iris.median()
# Sepal.Length    5.80
# Sepal.Width     3.00
# Petal.Length    4.35
# Petal.Width     1.30
# dtype: float64

# %% [markdown]
# `Apply Method`

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
def double_make(s):
  return s*2

# %%
iris[['Sepal.Width','Petal.Width']].apply(double_make)
# Out:
#      Sepal.Width  Petal.Width
# 0            7.0          0.4
# 1            6.0          0.4
# 2            6.4          0.4
# 3            6.2          0.4
# 4            7.2          0.4
# ..           ...          ...
# 145          6.0          4.6
# 146          5.0          3.8
# 147          6.0          4.0
# 148          6.8          4.6
# 149          6.0          3.6
#
# [150 rows x 2 columns]

# %% [markdown]
# **Value Count**

# %%
iris['Species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# `Sorting`

# %%
iris.sort_values(by='Sepal.Length')
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
import numpy as np
n1= np.array([[1,2,3,4],[6,7,8,9]])
n1.shape
# Out:
# (2, 4)
